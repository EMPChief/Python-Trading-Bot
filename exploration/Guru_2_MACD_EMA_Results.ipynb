# %%
import os
import plotly.graph_objects as go
import pandas as pd
import sys
sys.path.append("../")

# %%
from infrastructure.instrument_collection import instrumentCollection

# %%
def load_results(ic):
    res = []
    trades = []
    our_curr = ['USD', 'GBP', 'JPY', 'SEK', 'CHF', 'AUD', 'CAD', 'HKD']
    for p1 in our_curr:
        for p2 in our_curr:
            pair = f"{p1}_{p2}"
            if pair in ic.instruments_dict.keys():
                res.append(pd.read_csv(
                    f"../data/result/macd_ema_res_{pair}.csv"))
                trades.append(pd.read_csv(
                    f"../data/result/trades/macd_ema_trades_{pair}.csv"))
    return pd.concat(res), pd.concat(trades)

# %%
instrumentCollection.LoadInstruments('../data/')

# %%
df_results, df_trades = load_results(instrumentCollection)
df_results.reset_index(drop=True, inplace=True)
df_trades.reset_index(drop=True, inplace=True)

# %%
df_results.head()
# Out:
#    Unnamed: 0     pair  slow  fast  ema  result  signal
# 0           0  USD_JPY    26    12   50   -14.5       9
# 1           1  USD_JPY    26    12  100   -22.5       9
# 2           2  USD_JPY    26    12   50    -6.0      12
# 3           3  USD_JPY    26    12  100    -2.0      12
# 4           4  USD_JPY    26    18   50   -10.5       9

# %%
df_trades.head()
# Out:
#    Unnamed: 0  running  start_index_m5  profit_factor  loss_factor  \
# 0           0    False            2784            1.5         -1.0
# 1           1    False            5134            1.5         -1.0
# 2           2    False            9837            1.5         -1.0
# 3           3    False           10893            1.5         -1.0
# 4           4    False           12284            1.5         -1.0
#
#    start_price_buy  trigger_price_buy  start_price_sell  trigger_price_sell  \
# 0          104.320            104.320           104.336             104.336
# 1          104.571            104.571           104.585             104.585
# 2          110.550            110.550           110.568             110.568
# 3          112.534            112.534           112.550             112.550
# 4          113.389            113.389           113.403             113.403
#
#    SIGNAL  ...        TP       SL  result                   end_time  \
# 0       1  ...  104.5505  104.193    -1.0  2016-10-14 14:00:00+00:00
# 1       1  ...  105.0050  104.305    -1.0  2016-10-27 03:30:00+00:00
# 2       1  ...  111.1395  110.187    -1.0  2016-11-18 11:50:00+00:00
# 3       1  ...  113.2565  112.079     1.5  2016-11-24 07:35:00+00:00
# 4       1  ...  113.8980  113.073     1.5  2016-11-30 15:55:00+00:00
#
#                   start_time slow fast  signal  ema     pair
# 0  2016-10-14 13:00:00+00:00   26   12       9   50  USD_JPY
# 1  2016-10-26 17:00:00+00:00   26   12       9   50  USD_JPY
# 2  2016-11-18 02:00:00+00:00   26   12       9   50  USD_JPY
# 3  2016-11-23 18:00:00+00:00   26   12       9   50  USD_JPY
# 4  2016-11-30 14:00:00+00:00   26   12       9   50  USD_JPY
#
# [5 rows x 22 columns]

# %%
df_results.columns
# Out:
# Index(['Unnamed: 0', 'pair', 'slow', 'fast', 'ema', 'result', 'signal'], dtype='object')

# %%
# look at the results grouped by setting
gr = df_results.groupby(
    by=['slow', 'fast', 'ema', 'signal'], as_index=False).sum()

# %%
# sort descending, best result at the top
gr.sort_values(by='result', ascending=False, inplace=True)

# %%
gr.head()
# Out:
#     slow  fast  ema  signal  Unnamed: 0  \
# 15    52    18  100      12         330
# 13    52    18   50      12         308
# 7     26    18  100      12         154
# 14    52    18  100       9         286
# 5     26    18   50      12         132
#
#                                                  pair  result
# 15  USD_JPYUSD_SEKUSD_CHFUSD_CADUSD_HKDGBP_USDGBP_...    -9.5
# 13  USD_JPYUSD_SEKUSD_CHFUSD_CADUSD_HKDGBP_USDGBP_...   -15.5
# 7   USD_JPYUSD_SEKUSD_CHFUSD_CADUSD_HKDGBP_USDGBP_...  -144.0
# 14  USD_JPYUSD_SEKUSD_CHFUSD_CADUSD_HKDGBP_USDGBP_...  -144.5
# 5   USD_JPYUSD_SEKUSD_CHFUSD_CADUSD_HKDGBP_USDGBP_...  -156.0

# %%
# for the top setting, let's see what we have in terms of individual currency pairs
df_results_best = df_results[(df_results.ema == 50) & (
    df_results.fast == 18) & (df_results.slow == 52) & (df_results.signal == 9)]

# %%
df_results_best
# Out:
#      Unnamed: 0     pair  slow  fast  ema  result  signal
# 12           12  USD_JPY    52    18   50    35.0       9
# 28           12  USD_SEK    52    18   50   -48.0       9
# 44           12  USD_CHF    52    18   50   -16.0       9
# 60           12  USD_CAD    52    18   50     8.5       9
# 76           12  USD_HKD    52    18   50   -96.5       9
# 92           12  GBP_USD    52    18   50    21.0       9
# 108          12  GBP_JPY    52    18   50    28.0       9
# 124          12  GBP_CHF    52    18   50    -1.0       9
# 140          12  GBP_AUD    52    18   50   -18.5       9
# 156          12  GBP_CAD    52    18   50   -14.5       9
# 172          12  GBP_HKD    52    18   50    10.0       9
# 188          12  CHF_JPY    52    18   50    -2.0       9
# 204          12  CHF_HKD    52    18   50   -41.0       9
# 220          12  AUD_USD    52    18   50     6.0       9
# 236          12  AUD_JPY    52    18   50    14.5       9
# 252          12  AUD_CHF    52    18   50    -5.5       9
# 268          12  AUD_CAD    52    18   50    -6.0       9
# 284          12  AUD_HKD    52    18   50   -16.5       9
# 300          12  CAD_JPY    52    18   50   -12.0       9
# 316          12  CAD_CHF    52    18   50   -33.0       9
# 332          12  CAD_HKD    52    18   50    10.5       9
# 348          12  HKD_JPY    52    18   50    20.0       9

# %%
# let's see the individual trades for the top setting
df_trades_best = df_trades[(df_trades.ema == 50) & (df_trades.fast == 18) & (
    df_trades.slow == 52) & (df_trades.signal == 9)].copy()

# %%
df_trades_best.columns
# Out:
# Index(['Unnamed: 0', 'running', 'start_index_m5', 'profit_factor',
#        'loss_factor', 'start_price_buy', 'trigger_price_buy',
#        'start_price_sell', 'trigger_price_sell', 'SIGNAL', 'start_price',
#        'trigger_price', 'TP', 'SL', 'result', 'end_time', 'start_time', 'slow',
#        'fast', 'signal', 'ema', 'pair'],
#       dtype='object')

# %%
df_trades_best['start_time'] = pd.to_datetime(df_trades_best['start_time'])
df_trades_best['end_time'] = pd.to_datetime(df_trades_best['end_time'])


df_trades_best['duration_h'] = (
    df_trades_best['end_time'] - df_trades_best['start_time']).dt.total_seconds() / 3600
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 3
#       1 # let's see how long trades last
#       2 df_trades_best['duration_h'] = (
# ----> 3     df_trades_best.end_time - df_trades_best.start_time).dt.total_seconds() / 3600
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df_trades_best['duration_h'].describe()

# %%
# win percentage
wp = (df_trades_best[df_trades_best.result >
      0].shape[0] / df_trades_best.shape[0]) * 100
print("Win percentage", wp)

# %%
# we will take a look at the cumulative gains, so sort by end_time
df_trades_best.sort_values(by='end_time', inplace=True)

# %%
df_trades_best['CUM_RES'] = df_trades_best.result.cumsum()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df_trades_best.end_time,
    y=df_trades_best['CUM_RES'],
    line=dict(width=2)
))

fig.update_yaxes(
    gridcolor="#1f292f"
)
fig.update_xaxes(
    gridcolor="#1f292f"
)

fig.update_layout(
    margin=dict(l=10, r=10, b=10, t=10),
    paper_bgcolor="#2c303c",
    plot_bgcolor="#2c303c",
    font=dict(size=8, color="#e1e1e1"),
    height=400
)

fig.show()
