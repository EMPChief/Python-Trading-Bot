# %%
import pandas as pd
from plotting import CandlePlot
import sys
sys.path.append('../')

# %%
from technicals.indicator_cythone import BollingerBands, ATR, KeltnerChannels

# %%
df = pd.read_csv("../data/candles/EUR_USD_H1.csv")

# %%
df_an = df.copy()

# %%
df_an = KeltnerChannels(df_an)

# %%
dfp = df_an.iloc[-200:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=['EMA', 'KeUp', 'KeLo'])

# %%
print("hello")
