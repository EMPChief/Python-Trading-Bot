# %%
import pandas as pd
from plotting import CandlePlot
import sys
sys.path.append('../')

# %%
from technicals.indicators import *

# %%
df = pd.read_csv("../data/candles/EUR_USD_H1.csv")

# %%
df_an = df.copy()

# %%
df_an = MACD(df_an)

# %%
dfp = df_an.iloc[-500:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=[])

# %%
print(df.columns)

# %%
cp = CandlePlot(dfp, candles=False)
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SIGNAL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 cp = CandlePlot(dfp, candles=False)
# ----> 2 cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/exploration/plotting.py:67, in CandlePlot.show_plot(self, width, height, nticks, line_traces, sec_traces)
#      66 def show_plot(self, width: int = 1500, height: int = 800, nticks: int = 5, line_traces: list = [], sec_traces: list = []):
# ---> 67     self.add_traces(line_traces)
#      68     self.add_traces(sec_traces, is_secondary=True)
#      69     self.update_layout(width, height, nticks)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/exploration/plotting.py:59, in CandlePlot.add_traces(self, line_traces, is_secondary)
#      55 def add_traces(self, line_traces: list, is_secondary: bool = False):
#      56     for t in line_traces:
#      57         self.fig.add_trace(go.Scatter(
#      58             x=self.df_plot.sTime,
# ---> 59             y=self.df_plot[t],
#      60             line=dict(width=2),
#      61             line_shape="spline",
#      62             name=t,
#      63             hovertext=t,
#      64         ), secondary_y=is_secondary)
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /run/media/empchief/Extra/programming/Linux/Trading-Bot/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'SIGNAL'
