# %%
import pandas as pd
from plotting import CandlePlot
import sys
sys.path.append('../')

# %%
from technicals.indicators import BollingerBands

# %%
df = pd.read_csv('../data/candles/AUD_CAD_H4.csv')

# %%
df_an = df.copy()

# %%
df_an = BollingerBands(df, n40, s=3)

# %%
cp = CandlePlot(df_an.iloc[-200:], candles=True)
cp.show_plot(line_traces=['BB_MA', 'BB_UP', 'BB_DN'])
