# %%
import pandas as pd
from plotting import CandlePlot
import sys
sys.path.append('../')

# %%
from technicals.indicators import *

# %%
df = pd.read_csv("../data/candles/EUR_USD_H1.csv")

# %%
df_an = df.copy()

# %%
df_an = MACD(df_an)

# %%
dfp = df_an.iloc[-500:]
cp = CandlePlot(dfp, candles=True)
cp.show_plot(line_traces=[], sec_traces=[])

# %%
import plotly.graph_objects as go

# %%
cp = CandlePlot(dfp, candles=False)
cp.fig.add_trace(go.Bar(
    x=cp.df_plot.sTime,
    y=cp.df_plot.HIST,
    name='HIST',
))
cp.show_plot(line_traces=['SIGNAL', 'MACD'], sec_traces=[])
